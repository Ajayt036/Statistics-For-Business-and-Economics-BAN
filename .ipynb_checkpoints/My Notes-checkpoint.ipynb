# %% [markdown]
# # CHAPTER 2

# %% [markdown]
# ### 1. Graphical Summaries from Categorical and quantative data:
#
#
# Histogram - For frequency distribution of values in quant. Column ( mostly used to show value in bins).
# <BR>
# Barchart = For distribution of values in categorical Column (for abs. Number of values).
# <BR>
# Dot Plot - Bar chart of Quant columns (shows distribution of values in quant column.) but thos can be replaced by bar chart with width manipulation.
# <BR>
# Stem and Leaf - A better version of Hsitogram, It shows actual values of data in the form of histogram. best when data values are close to each other.
# <BR>
# Pie chart = For relative frequency distribution. ( mostly used for Categorical column)
# <BR>
# CrossTab = To put one varible(qual.) on x and another(quant. in class intervals mostly) on y axis to see summary.
# <BR>
# Scatter Plot - Used to see relation between two Quantative variables.
# <BR>
# Side by Side Bar chart - Compare two categorical variables
# <BR>
# Stacked Bar char: compare relative frequency of two variables.
#
#
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# _______________________________________________________________________________________________________________

# %% [markdown]
# # Chapter 3: Descriptive statistics

# %% [markdown]
# ### 1. Trimming Data for mean calculations
#
# - It is better to use the median than the mean as a measure
# of central location when a data set contains extreme
# values. Another measure that is sometimes used when
# extreme values are present is the trimmed mean. The
# trimmed mean is obtained by deleting a percentage of
# the smallest and largest values from a data set and then
# computing the mean of the remaining values. For example,
# the 5% trimmed mean is obtained by removing the
# smallest 5% and the largest 5% of the data values and then
# computing the mean of the remaining values.

# %% [markdown]
# ### 2. Weighted Mean in my Language:
#
# - Lets say three popular people: Elon Musk, Bill Gates and Jeff Bezoz want to sell their house.
# - Musk says i will sell my property for 300 USD per Sq. feet.
# - Gates says i will sell my property for 200 USD per Sq. feet.
# - Bezoz says i will sell my property for 400 USD per Sq. feet.
#
# **Logic** - Now, if one person on this planet bought all three houses of these celebraties alone. How much he paid overall for per Sq. inch?
# - See the trick is to calculate the mean of something which itself is mean of something. In these cases we need one more parameter called "Weights". Weight is nothing but overall value of Area of each house. Suppose area of house are.
# - Musk house: 3000 Sq ft.
# - Gates house: 5000 Sq ft.
# - Bezoz house: 1000 Sq ft.
# <BR>
#
# **Solution** - Answer will be first convert all prices w.r.t to full weights and then divide ny total weights.
# - 200(3000) + 200(4000) +400(1000)/8000 = 1400050 USD per Sq ft.
# - Please note that the answer obtrained is w.r.t per weight (per sq ft. in this example), and hence is called wighted average.

# %% [markdown]
# ### 3. The geometric mean is a measure of location that is calculated by Finding the nth root of the product of n value.
# - The geometric mean is often used in analyzing growth rates in financial data. Lets take an example:
# - Suppose Tarun invested 100 USD in investment for 5 years and return per year is:
#
#     <BR>
#     2021: -6%
#     <BR>
#     2021: -8%
#     <BR>
#     2021: -4%
#     <BR>
#     2021:  2%
#     <BR>
#     2021:  5.4%
#     <BR>
#
# - Can you tell me what was the average Profit of lost percent per year(Average annual growth) did i get from this investemnent?
#
# **Logic**
# <BR>
# - First Step: Calculate growth rate for each year. (Per cent return - 1)
# - Second Step: Take Geometric mean of growth rates.
# - Third Step: substract the grwoath rate GM from 1 to calculate the average annual growth per year
#
# **Solution:**
# <BR>
# **Step A:**
# - Growth rate 2021: (1 - (6/100)   = -0.94     # "-" because growth is negative
# - Growth rate 2021: (1 - (8/100)   = -0.92
# - Growth rate 2021: (1 - (4/100)   = -0.96
# - Growth rate 2021: (1 + (2/100)   =  1.02     # "+" because growth is positive
# - Growth rate 2021: (1 + (5.4/100) =  1.54
#
# **Step B:**
# <BR>
# GM = (0.94* 0.92* 0.96*1.02*1.054)**(1/5)  = 0.97    # "1/5" because total year = 5
#
# **Step C:**
# (0.97-1)*100 = -2.25%
# - Hence Average Annual retun obtaines using GM of Growth factor is -2.25%
# - Also if i want to see what is the actual money i recieved after 5 years: investement times (growth factor multiplication)
# - (0.94* 0.92* 0.96*1.02*1.054) = 89.25 USD
# - To summarize, Tarun's invested USD 100 for 5 years became 89.25 with average annual loss of -2.25%

# %% [markdown]
# ### 4. Chebyshev’s Theorem
#
# - Chebyshev’s theorem enables us to make statements about the MINIMUM proportion of data values
# that must be within a specified number of standard deviations of the mean **FOR ANY DISTRIBUTION**
#
# - At least (1 - (1/z)^ 2) of the data values must be within z standard deviations of the mean,
# where z is any value greater than 1
# -  At least .75, or 75%, of the data values must be within z ! 2 standard deviations of
# the mean.
# - At least .89, or 89%, of the data values must be within z ! 3 standard deviations of
# the mean.
# - Note that z has to be integer
# <BR>
# - One of the advantages of Chebyshev’s theorem is that it applies to any data set regardless
# of the shape of the distribution of the data.
# - If you know that your data follow the normal distribution, then use Normal distribution 68-95-99 rule. Otherwise, Chebyshev’s Theorem might be your best choice.
#
#  **Link** - https://statisticsbyjim.com/basics/chebyshevs-theorem-in-statistics/

# %% [markdown]
# ### 5. Outlier
#
# - Data points with unusually large or unusually small values are called outliers
# -  An outlier may be a data value that has been incorrectly recorded. If so, it can be corrected before further analysis.
# - An outlier may be an unusual data value that has been recorded correctly and belongs in the data set. In such cases it should remain.
#
# **Two approahes to remove outlier**:
# <BR>
# A. using z score, Z = deviation from mean/standard deviation
# <BR>
# B. Outside Limit:
# <BR>
# Lower Limit =  Q1 - 1.5(IQR)
# <BR>
# Upper Limit =  Q3 - 1.5(IQR)

# %% [markdown]
# ### 6. How To read a Box Plot?
#
# - A boxplot is a graphical display of data based on a !ve-number summary
#
# ![image-3.png](attachment:image-3.png)
#
# 1. First is the box between 1st and 3rd quartile, it reflects the 50% of data.
# 2. Second is the median for cental value of data.
# 3. Third is the Limits of boxplot, made to separate outliers based on Q1-IQR , Q3+IQR. Please note that These are not max or min values form data.
# 4. Fourth are the whiskes line that connects to min amd max values with in the limits of boxplot
# 5. Outliers are the points outside of boxplot lmits. They will intain max or min valiue of data.

# %% [markdown]
# ### 7. COVARIANCE:

# %% [markdown]
# - covariance is defined as a descriptive measure of the linear association between two variables.
# - It shows the behaviour of one columns with repect to other like sactter diagram.
# <BR>
#
# - If there are two varbles, find deviation from each column for each value.
# - And then mutiplay corrponding deviation for each observation of two variables
# - And add them in last to get value of covarince
#
#
# ![image-2.png](attachment:image-2.png)
#
# - It might appear that a large positive value for the covariance
# indicates a strong positive linear relationship and that a large negative value indicates a strong
# negative linear relationship. However, one problem with using covariance as a measure of the
# strength of the linear relationship is that the value of the covariance depends on the units of measurment.
# - For Example: For a same problem, Measuring the height in inches, however,
# gives us much larger numerical values forthan when we measure height in feet.when in fact the relationship does
# not change. Hence we needed correlation coef!cient.
#
# **Refrence: Book Page 142**

# %% [markdown]
# ## 8. Correlation Coefficient

# %% [markdown]
# - The division of covariance with product of(Deviation of variable and Variable 2 ) gives us correlation coffiecent. This is formed to neutralise the problem of covarince's different values for same data but diefferent measuring unit.
# - Note that correlation provides a measure of linear association and not necessarily causation- This is very important there is difference bwteen a linear relation and causation. I have read this in GMAT CR questions.

# %% [markdown]
# ## 9. KPI
#
# KPI stands for key performance indicator, a quantifiable measure of performance over time for a specific objective. KPIs provide targets for teams to shoot for, milestones to gauge progress, and insights that help people across the organization make better decisions.
#
# Example: Remeber from using Wiley APP, A graph used to appear on right side, which gave a target of 100% in donut shape KPI. it used to give me a goal of 100% and even shows my progress.
#
# **Example:**
# - From finance and HR to marketing and sales, key performance indicators help every area of the business move forward at the strat.
# - KPI Meaning vs Metrics Meaning: Metrics measure the success of everyday business activities that support your KPIs. While they impact your outcomes, they’re not the most critical measures

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 10. Chapter Summary:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ______________________________________________________________________________________________________________

# %% [markdown]
# ________________________________________________________________________________________________________________________
